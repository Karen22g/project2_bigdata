# %%
from pymongo import MongoClient
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import math
import numpy as np
import json

# %% [markdown]
# ### Crear bd mongos en azure

# %%
# Connection string (replace with your connection details)
client = MongoClient("mongodb://karenproject2:z9PkVdtemdbbrO38N9RO9wEKW0xenBwKw3M1HETe2eDjPI4Abkk8aeN7HUAIuJWdDNV1VAMLgx8oACDbU7EXFw==@karenproject2.mongo.cosmos.azure.com:10255/?ssl=true&replicaSet=globaldb&retrywrites=false&maxIdleTimeMS=120000&appName=@karenproject2@")
# OR for Atlas: 
# client = MongoClient("mongodb+srv://username:password@cluster.mongodb.net/")

db = client.sample_supplies
collection = db.sales

# Test connection
print(f"Total listings: {collection.count_documents({})}")
# Out:
# C:\Users\kgome\AppData\Local\Temp\ipykernel_27720\3687266494.py:2: UserWarning: You appear to be connected to a CosmosDB cluster. For more information regarding feature compatibility and support please visit https://www.mongodb.com/supportability/cosmosdb
#   client = MongoClient("mongodb://karenproject2:z9PkVdtemdbbrO38N9RO9wEKW0xenBwKw3M1HETe2eDjPI4Abkk8aeN7HUAIuJWdDNV1VAMLgx8oACDbU7EXFw==@karenproject2.mongo.cosmos.azure.com:10255/?ssl=true&replicaSet=globaldb&retrywrites=false&maxIdleTimeMS=120000&appName=@karenproject2@")
# Total listings: 0

# %%
collection.drop()

# %%
#Esto de subir en batches es importante hacerlo porque cuando se intenta con mongoimport o con mongorestore
#No da para subir los 5000 registros de una, entonces estoy intentando subirlo en grupos
#Mismo problema que nos ha ocurrido con dynamoDB

# %%
def clean_doc(doc):
    # Convertir _id.$oid a string
    if isinstance(doc.get("_id"), dict) and "$oid" in doc["_id"]:
        doc["_id"] = doc["_id"]["$oid"]

    # Convertir fechas
    if isinstance(doc.get("saleDate"), dict) and "$date" in doc["saleDate"]:
        doc["saleDate"] = doc["saleDate"]["$date"]

    # Convertir precios dentro de items
    if "items" in doc:
        for item in doc["items"]:
            if isinstance(item.get("price"), dict) and "$numberDecimal" in item["price"]:
                item["price"] = float(item["price"]["$numberDecimal"])
    return doc

# %%
# Leer el JSON exportado
with open("./backup/sales.json", "r", encoding="utf-8") as f:
    data = json.load(f)

cleaned = [clean_doc(doc) for doc in data]

# Insertar en lotes pequeños (ej. 50 documentos por lote)
batch_size = 50
for i in range(0, len(data), batch_size):
    batch = data[i:i+batch_size]
    try:
        collection.insert_many(batch, ordered=False)
        print(f"Lote {i//batch_size+1} insertado con éxito ({len(batch)} docs)")
    except Exception as e:
        print(f"Error en lote {i//batch_size+1}: {e}")
# Out:
# Lote 1 insertado con éxito (50 docs)
# Error en lote 2: batch op errors occurred, full error: {'writeErrors': [{'index': 25, 'code': 16500, 'errmsg': "Error=16500, RetryAfterMs=8, Details='Insert error.", 'op': {'_id': '5bd761dcae323e45a93cd033', 'saleDate': '2016-11-08T01:26:43.191Z', 'items': [{'name': 'laptop', 'tags': ['electronics', 'school', 'office'], 'price': 1150.97, 'quantity': 5}, {'name': 'notepad', 'tags': ['office', 'writing', 'school'], 'price': 24.58, 'quantity': 2}, {'name': 'backpack', 'tags': ['school', 'travel', 'kids'], 'price': 169.68, 'quantity': 1}, {'name': 'binder', 'tags': ['school', 'general', 'organization'], 'price': 18.31, 'quantity': 8}, {'name': 'binder', 'tags': ['school', 'general', 'organization'], 'price': 28.24, 'quantity': 6}, {'name': 'printer paper', 'tags': ['office', 'stationary'], 'price': 42.37, 'quantity': 4}, {'name': 'pens', 'tags': ['writing', 'office', 'school', 'stationary'], 'price': 46.55, 'quantity': 4}, {'name': 'notepad', 'tags': ['office', 'writing', 'school'], 'price': 25.23, 'quantity': 5}, {'name': 'notepad', 'tags': ['office', 'writing', 'school'], 'price': 13.19, 'quantity': 5}], 'storeLocation': 'San Diego', 'customer': {'gender': 'F', 'age': 30, 'email': 'kangas@odwub.vi', 'satisfaction': 3}, 'couponUsed': False, 'purchaseMethod': 'In store'}}, {'index': 26, 'code': 16500, 'errmsg': "Error=16500, RetryAfterMs=8, Details='Insert error.", 'op': {'_id': '5bd761dcae323e45a93cd034', 'saleDate': '2016-12-27T07:14:16.123Z', 'items': [{'name': 'binder', 'tags': ['school', 'general', 'organization'], 'price': 20.83, 'quantity': 3}, {'name': 'laptop', 'tags': ['electronics', 'school', 'office'], 'price': 1204.33, 'quantity': 5}, {'name': 'pens', 'tags': ['writing', 'office', 'school', 'stationary'], 'price': 25.27, 'quantity': 3}, {'name': 'envelopes', 'tags': ['stationary', 'office', 'general'], 'price': 19.99, 'quantity': 6}, {'name': 'printer paper', 'tags': ['office', 'stationary'], 'price': 21.78, 'quantity': 8}, {'name': 'binder', 'tags': ['school', 'general', 'organization'], 'price': 13.23, 'quantity': 7}], 'storeLocation': 'Seattle', 'customer': {'gender': 'F', 'age': 44, 'email': 'acmumtuc@dehse.mx', 'satisfaction': 4}, 'couponUsed': False, 'purchaseMethod': 'In store'}}, {'index': 27, 'code': 16500, 'errmsg': "Error=16500, RetryAfterMs=8, Details='Insert error.", 'op': {'_id': '5bd761dcae323e45a93cd035', 'saleDate': '2017-12-29T22:39:41.487Z', 'items': [{'name': 'pens', 'tags': ['writing', 'office', 'school', 'stationary'], 'price': 72.04, 'quantity': 1}, {'name': 'envelopes', 'tags': ['stationary', 'office', 'general'], 'price': 23.18, 'quantity': 9}, {'name': 'backpack', 'tags': ['school', 'travel', 'kids'], 'price': 114.52, 'quantity': 4}, {'name': 'notepad', 'tags': ['office', 'writing', 'school'], 'price': 5.53, 'quantity': 2}, {'name': 'notepad', 'tags': ['office', 'writing', 'school'], 'price': 31.8, 'quantity': 3}, {'name': 'binder', 'tags': ['school', 'general', 'organization'], 'price': 19.24, 'quantity': 4}, {'name': 'envelopes', 'tags': ['stationary', 'office', 'general'], 'price': 7.87, 'quantity': 7}], 'storeLocation': 'Seattle', 'customer': {'gender': 'M', 'age': 23, 'email': 'pevu@razit.uy', 'satisfaction': 5}, 'couponUsed': False, 'purchaseMethod': 'In store'}}, {'index': 28, 'code': 16500, 'errmsg': "Error=16500, RetryAfterMs=8, Details='Insert error.", 'op': {'_id': '5bd761dcae323e45a93cd036', 'saleDate': '2015-04-21T11:35:55.339Z', 'items': [{'name': 'envelopes', 'tags': ['stationary', 'office', 'general'], 'price': 8.61, 'quantity': 4}, {'name': 'envelopes', 'tags': ['stationary', 'office', 'general'], 'price': 13.54, 'quantity': 7}, {'name': 'pens', 'tags': ['writing', 'office', 'school', 'stationary'], 'price': 16.94, 'quantity': 1}, {'name': 'notepad', 'tags': ['office', 'writing', 'school'], 'price': 21.84, 'quantity': 4}, {'name': 'printer paper', 'tags': ['office', 'stationary'], 'price': 45.68, 'quantity': 4}, {'name': 'notepad', 'tags': ['office', 'writing', 'school'], 'pr ...
# Error en lote 3: batch op errors occurred, full error: {'writeErrors': [{'index': 12, 'code': 16500, 'errmsg': "Error=16500, RetryAfterMs=10, Details='Insert error.", 'op': {'_id': '5bd761dcae323e45a93cd058', 'saleDate': '2017-08-17T00:40:46.374Z', 'items': [{'name': 'binder', 'tags': ['school', 'general', 'organization'], 'price': 15.75, 'quantity': 5}, {'name': 'printer paper', 'tags': ['office', 'stationary'], 'price': 24.95, 'quantity': 4}], 'storeLocation': 'San Diego', 'customer': {'gender': 'M', 'age': 18, 'email': 'gacaf@pob.fj', 'satisfaction': 4}, 'couponUsed': False, 'purchaseMethod': 'Online'}}, {'index': 13, 'code': 16500, 'errmsg': "Error=16500, RetryAfterMs=10, Details='Insert error.", 'op': {'_id': '5bd761dcae323e45a93cd059', 'saleDate': '2013-11-12T20:48:23.93Z', 'items': [{'name': 'backpack', 'tags': ['school', 'travel', 'kids'], 'price': 129.88, 'quantity': 5}, {'name': 'laptop', 'tags': ['electronics', 'school', 'office'], 'price': 1082.75, 'quantity': 3}, {'name': 'binder', 'tags': ['school', 'general', 'organization'], 'price': 23.0, 'quantity': 3}, {'name': 'envelopes', 'tags': ['stationary', 'office', 'general'], 'price': 23.21, 'quantity': 4}, {'name': 'envelopes', 'tags': ['stationary', 'office', 'general'], 'price': 5.42, 'quantity': 1}, {'name': 'binder', 'tags': ['school', 'general', 'organization'], 'price': 20.55, 'quantity': 7}, {'name': 'notepad', 'tags': ['office', 'writing', 'school'], 'price': 32.53, 'quantity': 2}, {'name': 'notepad', 'tags': ['office', 'writing', 'school'], 'price': 29.04, 'quantity': 3}, {'name': 'printer paper', 'tags': ['office', 'stationary'], 'price': 32.15, 'quantity': 3}, {'name': 'notepad', 'tags': ['office', 'writing', 'school'], 'price': 23.72, 'quantity': 4}], 'storeLocation': 'Seattle', 'customer': {'gender': 'F', 'age': 35, 'email': 'ka@ninocudid.pk', 'satisfaction': 2}, 'couponUsed': False, 'purchaseMethod': 'In store'}}, {'index': 14, 'code': 16500, 'errmsg': "Error=16500, RetryAfterMs=10, Details='Insert error.", 'op': {'_id': '5bd761dcae323e45a93cd05a', 'saleDate': '2013-01-10T01:10:15.493Z', 'items': [{'name': 'pens', 'tags': ['writing', 'office', 'school', 'stationary'], 'price': 20.17, 'quantity': 1}, {'name': 'pens', 'tags': ['writing', 'office', 'school', 'stationary'], 'price': 51.7, 'quantity': 4}, {'name': 'binder', 'tags': ['school', 'general', 'organization'], 'price': 14.82, 'quantity': 3}], 'storeLocation': 'Seattle', 'customer': {'gender': 'M', 'age': 62, 'email': 'bimvo@kub.bq', 'satisfaction': 1}, 'couponUsed': False, 'purchaseMethod': 'In store'}}, {'index': 15, 'code': 16500, 'errmsg': "Error=16500, RetryAfterMs=10, Details='Insert error.", 'op': {'_id': '5bd761dcae323e45a93cd05b', 'saleDate': '2014-07-14T01:12:23.83Z', 'items': [{'name': 'binder', 'tags': ['school', 'general', 'organization'], 'price': 13.93, 'quantity': 2}, {'name': 'notepad', 'tags': ['office', 'writing', 'school'], 'price': 18.77, 'quantity': 5}, {'name': 'envelopes', 'tags': ['stationary', 'office', 'general'], 'price': 13.71, 'quantity': 10}, {'name': 'envelopes', 'tags': ['stationary', 'office', 'general'], 'price': 13.46, 'quantity': 4}, {'name': 'binder', 'tags': ['school', 'general', 'organization'], 'price': 23.3, 'quantity': 5}, {'name': 'pens', 'tags': ['writing', 'office', 'school', 'stationary'], 'price': 64.47, 'quantity': 5}, {'name': 'laptop', 'tags': ['electronics', 'school', 'office'], 'price': 893.66, 'quantity': 3}], 'storeLocation': 'Denver', 'customer': {'gender': 'F', 'age': 65, 'email': 'kapdov@vihtuzi.tv', 'satisfaction': 3}, 'couponUsed': False, 'purchaseMethod': 'Online'}}, {'index': 16, 'code': 16500, 'errmsg': "Error=16500, RetryAfterMs=10, Details='Insert error.", 'op': {'_id': '5bd761dcae323e45a93cd05c', 'saleDate': '2016-09-29T21:06:04.999Z', 'items': [{'name': 'binder', 'tags': ['school', 'general', 'organization'], 'price': 17.02, 'quantity': 3}, {'name': 'backpack', 'tags': ['school', 'travel', 'kids'], 'price': 153.74, 'quantity': 4},  ...
# Error en lote 4: batch op errors occurred, full error: {'writeErrors': [{'index': 40, 'code': 16500, 'errmsg': "Error=16500, RetryAfterMs=8, Details='Insert error.", 'op': {'_id': '5bd761dcae323e45a93cd0a6', 'saleDate': '2015-04-16T00:18:22.046Z', 'items': [{'name': 'printer paper', 'tags': ['office', 'stationary'], 'price': 28.33, 'quantity': 1}, {'name': 'notepad', 'tags': ['office', 'writing', 'school'], 'price': 8.61, 'quantity': 2}], 'storeLocation': 'Denver', 'customer': {'gender': 'M', 'age': 32, 'email': 'rimla@sil.np', 'satisfaction': 3}, 'couponUsed': False, 'purchaseMethod': 'Phone'}}, {'index': 41, 'code': 16500, 'errmsg': "Error=16500, RetryAfterMs=8, Details='Insert error.", 'op': {'_id': '5bd761dcae323e45a93cd0a7', 'saleDate': '2016-01-11T20:50:24.76Z', 'items': [{'name': 'laptop', 'tags': ['electronics', 'school', 'office'], 'price': 560.93, 'quantity': 1}, {'name': 'binder', 'tags': ['school', 'general', 'organization'], 'price': 29.85, 'quantity': 2}, {'name': 'printer paper', 'tags': ['office', 'stationary'], 'price': 43.31, 'quantity': 10}], 'storeLocation': 'Austin', 'customer': {'gender': 'F', 'age': 16, 'email': 'uma@obu.la', 'satisfaction': 1}, 'couponUsed': False, 'purchaseMethod': 'Online'}}, {'index': 42, 'code': 16500, 'errmsg': "Error=16500, RetryAfterMs=8, Details='Insert error.", 'op': {'_id': '5bd761dcae323e45a93cd0a8', 'saleDate': '2017-02-23T06:07:44.124Z', 'items': [{'name': 'pens', 'tags': ['writing', 'office', 'school', 'stationary'], 'price': 7.96, 'quantity': 4}, {'name': 'laptop', 'tags': ['electronics', 'school', 'office'], 'price': 1582.98, 'quantity': 3}, {'name': 'envelopes', 'tags': ['stationary', 'office', 'general'], 'price': 11.39, 'quantity': 7}, {'name': 'notepad', 'tags': ['office', 'writing', 'school'], 'price': 37.6, 'quantity': 5}, {'name': 'notepad', 'tags': ['office', 'writing', 'school'], 'price': 25.54, 'quantity': 1}], 'storeLocation': 'Seattle', 'customer': {'gender': 'M', 'age': 51, 'email': 'davnuwcu@no.vi', 'satisfaction': 5}, 'couponUsed': False, 'purchaseMethod': 'In store'}}, {'index': 43, 'code': 16500, 'errmsg': "Error=16500, RetryAfterMs=8, Details='Insert error.", 'op': {'_id': '5bd761dcae323e45a93cd0a9', 'saleDate': '2016-09-08T06:53:24.585Z', 'items': [{'name': 'binder', 'tags': ['school', 'general', 'organization'], 'price': 17.43, 'quantity': 10}, {'name': 'notepad', 'tags': ['office', 'writing', 'school'], 'price': 21.5, 'quantity': 3}, {'name': 'notepad', 'tags': ['office', 'writing', 'school'], 'price': 13.75, 'quantity': 4}, {'name': 'notepad', 'tags': ['office', 'writing', 'school'], 'price': 6.17, 'quantity': 2}], 'storeLocation': 'Austin', 'customer': {'gender': 'F', 'age': 61, 'email': 'bizlov@mu.vu', 'satisfaction': 5}, 'couponUsed': False, 'purchaseMethod': 'In store'}}, {'index': 44, 'code': 16500, 'errmsg': "Error=16500, RetryAfterMs=8, Details='Insert error.", 'op': {'_id': '5bd761dcae323e45a93cd0aa', 'saleDate': '2014-08-16T22:35:32.771Z', 'items': [{'name': 'notepad', 'tags': ['office', 'writing', 'school'], 'price': 27.19, 'quantity': 3}, {'name': 'envelopes', 'tags': ['stationary', 'office', 'general'], 'price': 16.74, 'quantity': 1}, {'name': 'notepad', 'tags': ['office', 'writing', 'school'], 'price': 16.93, 'quantity': 1}, {'name': 'laptop', 'tags': ['electronics', 'school', 'office'], 'price': 656.84, 'quantity': 2}, {'name': 'envelopes', 'tags': ['stationary', 'office', 'general'], 'price': 21.3, 'quantity': 10}, {'name': 'backpack', 'tags': ['school', 'travel', 'kids'], 'price': 101.15, 'quantity': 2}, {'name': 'pens', 'tags': ['writing', 'office', 'school', 'stationary'], 'price': 18.59, 'quantity': 4}], 'storeLocation': 'London', 'customer': {'gender': 'M', 'age': 61, 'email': 'lo@jakwaepu.bg', 'satisfaction': 1}, 'couponUsed': False, 'purchaseMethod': 'Online'}}, {'index': 45, 'code': 16500, 'errmsg': "Error=16500, RetryAfterMs=8, Details='Insert error.", 'op': {'_id': '5bd761dcae323e45a93cd0ab', 'saleDate': '2016-01-02T14:27:48 ...
# Error en lote 5: batch op errors occurred, full error: {'writeErrors': [{'index': 12, 'code': 16500, 'errmsg': "Error=16500, RetryAfterMs=9, Details='Insert error.", 'op': {'_id': '5bd761dcae323e45a93cd0bc', 'saleDate': '2015-12-27T21:59:07.199Z', 'items': [{'name': 'envelopes', 'tags': ['stationary', 'office', 'general'], 'price': 8.34, 'quantity': 6}, {'name': 'backpack', 'tags': ['school', 'travel', 'kids'], 'price': 146.47, 'quantity': 3}, {'name': 'notepad', 'tags': ['office', 'writing', 'school'], 'price': 21.64, 'quantity': 3}, {'name': 'pens', 'tags': ['writing', 'office', 'school', 'stationary'], 'price': 37.74, 'quantity': 3}, {'name': 'laptop', 'tags': ['electronics', 'school', 'office'], 'price': 1324.86, 'quantity': 4}, {'name': 'notepad', 'tags': ['office', 'writing', 'school'], 'price': 23.13, 'quantity': 2}, {'name': 'binder', 'tags': ['school', 'general', 'organization'], 'price': 24.38, 'quantity': 4}, {'name': 'envelopes', 'tags': ['stationary', 'office', 'general'], 'price': 11.46, 'quantity': 8}, {'name': 'notepad', 'tags': ['office', 'writing', 'school'], 'price': 30.96, 'quantity': 5}], 'storeLocation': 'Austin', 'customer': {'gender': 'F', 'age': 61, 'email': 'uranozi@ze.sc', 'satisfaction': 4}, 'couponUsed': False, 'purchaseMethod': 'In store'}}, {'index': 13, 'code': 16500, 'errmsg': "Error=16500, RetryAfterMs=9, Details='Insert error.", 'op': {'_id': '5bd761dcae323e45a93cd0bd', 'saleDate': '2016-03-31T07:02:02.328Z', 'items': [{'name': 'notepad', 'tags': ['office', 'writing', 'school'], 'price': 10.58, 'quantity': 5}, {'name': 'notepad', 'tags': ['office', 'writing', 'school'], 'price': 32.77, 'quantity': 3}, {'name': 'binder', 'tags': ['school', 'general', 'organization'], 'price': 12.73, 'quantity': 2}], 'storeLocation': 'London', 'customer': {'gender': 'F', 'age': 40, 'email': 'fu@bolav.kn', 'satisfaction': 5}, 'couponUsed': False, 'purchaseMethod': 'Phone'}}, {'index': 14, 'code': 16500, 'errmsg': "Error=16500, RetryAfterMs=9, Details='Insert error.", 'op': {'_id': '5bd761dcae323e45a93cd0be', 'saleDate': '2016-08-15T15:41:39.26Z', 'items': [{'name': 'printer paper', 'tags': ['office', 'stationary'], 'price': 10.31, 'quantity': 3}, {'name': 'pens', 'tags': ['writing', 'office', 'school', 'stationary'], 'price': 44.8, 'quantity': 3}, {'name': 'notepad', 'tags': ['office', 'writing', 'school'], 'price': 19.05, 'quantity': 1}, {'name': 'envelopes', 'tags': ['stationary', 'office', 'general'], 'price': 18.59, 'quantity': 4}, {'name': 'binder', 'tags': ['school', 'general', 'organization'], 'price': 24.2, 'quantity': 1}, {'name': 'envelopes', 'tags': ['stationary', 'office', 'general'], 'price': 24.48, 'quantity': 10}, {'name': 'notepad', 'tags': ['office', 'writing', 'school'], 'price': 25.23, 'quantity': 3}, {'name': 'backpack', 'tags': ['school', 'travel', 'kids'], 'price': 135.72, 'quantity': 2}], 'storeLocation': 'London', 'customer': {'gender': 'M', 'age': 28, 'email': 'lo@bakeve.sh', 'satisfaction': 4}, 'couponUsed': False, 'purchaseMethod': 'Online'}}, {'index': 15, 'code': 16500, 'errmsg': "Error=16500, RetryAfterMs=9, Details='Insert error.", 'op': {'_id': '5bd761dcae323e45a93cd0bf', 'saleDate': '2017-10-02T11:31:44.649Z', 'items': [{'name': 'envelopes', 'tags': ['stationary', 'office', 'general'], 'price': 15.45, 'quantity': 6}, {'name': 'notepad', 'tags': ['office', 'writing', 'school'], 'price': 9.58, 'quantity': 3}, {'name': 'notepad', 'tags': ['office', 'writing', 'school'], 'price': 18.39, 'quantity': 2}, {'name': 'envelopes', 'tags': ['stationary', 'office', 'general'], 'price': 13.07, 'quantity': 1}, {'name': 'printer paper', 'tags': ['office', 'stationary'], 'price': 33.9, 'quantity': 10}, {'name': 'notepad', 'tags': ['office', 'writing', 'school'], 'price': 9.59, 'quantity': 3}, {'name': 'binder', 'tags': ['school', 'general', 'organization'], 'price': 11.74, 'quantity': 4}, {'name': 'pens', 'tags': ['writing', 'office', 'school', 'stationary'], 'price': 39.31, 'quantity': 4}], 'sto ...
# Error en lote 6: batch op errors occurred, full error: {'writeErrors': [{'index': 12, 'code': 16500, 'errmsg': "Error=16500, RetryAfterMs=7, Details='Insert error.", 'op': {'_id': '5bd761dcae323e45a93cd0ee', 'saleDate': '2016-08-05T04:31:22.005Z', 'items': [{'name': 'binder', 'tags': ['school', 'general', 'organization'], 'price': 15.91, 'quantity': 5}, {'name': 'notepad', 'tags': ['office', 'writing', 'school'], 'price': 25.12, 'quantity': 1}, {'name': 'binder', 'tags': ['school', 'general', 'organization'], 'price': 11.78, 'quantity': 2}, {'name': 'notepad', 'tags': ['office', 'writing', 'school'], 'price': 37.14, 'quantity': 4}, {'name': 'laptop', 'tags': ['electronics', 'school', 'office'], 'price': 545.21, 'quantity': 4}, {'name': 'pens', 'tags': ['writing', 'office', 'school', 'stationary'], 'price': 28.51, 'quantity': 5}, {'name': 'pens', 'tags': ['writing', 'office', 'school', 'stationary'], 'price': 10.51, 'quantity': 3}, {'name': 'backpack', 'tags': ['school', 'travel', 'kids'], 'price': 138.28, 'quantity': 2}, {'name': 'printer paper', 'tags': ['office', 'stationary'], 'price': 49.74, 'quantity': 9}, {'name': 'envelopes', 'tags': ['stationary', 'office', 'general'], 'price': 13.99, 'quantity': 5}], 'storeLocation': 'Denver', 'customer': {'gender': 'M', 'age': 60, 'email': 'fekek@newo.et', 'satisfaction': 5}, 'couponUsed': False, 'purchaseMethod': 'In store'}}, {'index': 13, 'code': 16500, 'errmsg': "Error=16500, RetryAfterMs=7, Details='Insert error.", 'op': {'_id': '5bd761dcae323e45a93cd0ef', 'saleDate': '2014-07-18T10:17:24.789Z', 'items': [{'name': 'backpack', 'tags': ['school', 'travel', 'kids'], 'price': 183.65, 'quantity': 3}, {'name': 'laptop', 'tags': ['electronics', 'school', 'office'], 'price': 1406.35, 'quantity': 5}, {'name': 'notepad', 'tags': ['office', 'writing', 'school'], 'price': 26.33, 'quantity': 4}, {'name': 'pens', 'tags': ['writing', 'office', 'school', 'stationary'], 'price': 72.01, 'quantity': 1}, {'name': 'pens', 'tags': ['writing', 'office', 'school', 'stationary'], 'price': 35.62, 'quantity': 1}], 'storeLocation': 'Seattle', 'customer': {'gender': 'M', 'age': 20, 'email': 'iloldiz@afikuram.bh', 'satisfaction': 4}, 'couponUsed': False, 'purchaseMethod': 'Online'}}, {'index': 14, 'code': 16500, 'errmsg': "Error=16500, RetryAfterMs=7, Details='Insert error.", 'op': {'_id': '5bd761dcae323e45a93cd0f0', 'saleDate': '2013-02-24T15:44:08.6Z', 'items': [{'name': 'pens', 'tags': ['writing', 'office', 'school', 'stationary'], 'price': 20.29, 'quantity': 4}, {'name': 'notepad', 'tags': ['office', 'writing', 'school'], 'price': 20.48, 'quantity': 4}, {'name': 'envelopes', 'tags': ['stationary', 'office', 'general'], 'price': 22.12, 'quantity': 4}, {'name': 'binder', 'tags': ['school', 'general', 'organization'], 'price': 17.73, 'quantity': 3}, {'name': 'laptop', 'tags': ['electronics', 'school', 'office'], 'price': 1483.86, 'quantity': 1}, {'name': 'pens', 'tags': ['writing', 'office', 'school', 'stationary'], 'price': 30.1, 'quantity': 1}, {'name': 'binder', 'tags': ['school', 'general', 'organization'], 'price': 29.17, 'quantity': 3}, {'name': 'printer paper', 'tags': ['office', 'stationary'], 'price': 41.86, 'quantity': 2}], 'storeLocation': 'London', 'customer': {'gender': 'F', 'age': 19, 'email': 'gi@binvozfo.at', 'satisfaction': 4}, 'couponUsed': True, 'purchaseMethod': 'In store'}}, {'index': 15, 'code': 16500, 'errmsg': "Error=16500, RetryAfterMs=7, Details='Insert error.", 'op': {'_id': '5bd761dcae323e45a93cd0f1', 'saleDate': '2016-11-14T13:08:39.337Z', 'items': [{'name': 'envelopes', 'tags': ['stationary', 'office', 'general'], 'price': 19.9, 'quantity': 7}, {'name': 'binder', 'tags': ['school', 'general', 'organization'], 'price': 10.93, 'quantity': 3}, {'name': 'backpack', 'tags': ['school', 'travel', 'kids'], 'price': 165.96, 'quantity': 5}, {'name': 'notepad', 'tags': ['office', 'writing', 'school'], 'price': 36.69, 'quantity': 4}], 'storeLocation': 'Denver', 'customer': {'gender': 'M',  ...
# Error en lote 7: batch op errors occurred, full error: {'writeErrors': [{'index': 11, 'code': 16500, 'errmsg': "Error=16500, RetryAfterMs=11, Details='Insert error.", 'op': {'_id': '5bd761dcae323e45a93cd11f', 'saleDate': '2016-08-20T00:16:45.01Z', 'items': [{'name': 'pens', 'tags': ['writing', 'office', 'school', 'stationary'], 'price': 43.51, 'quantity': 4}, {'name': 'laptop', 'tags': ['electronics', 'school', 'office'], 'price': 1495.8, 'quantity': 2}, {'name': 'pens', 'tags': ['writing', 'office', 'school', 'stationary'], 'price': 52.88, 'quantity': 5}, {'name': 'envelopes', 'tags': ['stationary', 'office', 'general'], 'price': 7.79, 'quantity': 4}], 'storeLocation': 'New York', 'customer': {'gender': 'M', 'age': 58, 'email': 'feub@wepig.mm', 'satisfaction': 3}, 'couponUsed': True, 'purchaseMethod': 'In store'}}, {'index': 12, 'code': 16500, 'errmsg': "Error=16500, RetryAfterMs=11, Details='Insert error.", 'op': {'_id': '5bd761dcae323e45a93cd120', 'saleDate': '2013-12-04T07:57:09.171Z', 'items': [{'name': 'binder', 'tags': ['school', 'general', 'organization'], 'price': 12.17, 'quantity': 6}, {'name': 'pens', 'tags': ['writing', 'office', 'school', 'stationary'], 'price': 59.14, 'quantity': 1}, {'name': 'envelopes', 'tags': ['stationary', 'office', 'general'], 'price': 5.51, 'quantity': 10}, {'name': 'binder', 'tags': ['school', 'general', 'organization'], 'price': 22.86, 'quantity': 4}, {'name': 'backpack', 'tags': ['school', 'travel', 'kids'], 'price': 168.73, 'quantity': 3}, {'name': 'envelopes', 'tags': ['stationary', 'office', 'general'], 'price': 8.68, 'quantity': 5}, {'name': 'notepad', 'tags': ['office', 'writing', 'school'], 'price': 19.57, 'quantity': 1}, {'name': 'notepad', 'tags': ['office', 'writing', 'school'], 'price': 32.96, 'quantity': 3}], 'storeLocation': 'London', 'customer': {'gender': 'M', 'age': 47, 'email': 'bamu@jakasi.jm', 'satisfaction': 4}, 'couponUsed': False, 'purchaseMethod': 'In store'}}, {'index': 13, 'code': 16500, 'errmsg': "Error=16500, RetryAfterMs=11, Details='Insert error.", 'op': {'_id': '5bd761dcae323e45a93cd121', 'saleDate': '2015-08-01T16:37:08.513Z', 'items': [{'name': 'pens', 'tags': ['writing', 'office', 'school', 'stationary'], 'price': 66.25, 'quantity': 1}, {'name': 'printer paper', 'tags': ['office', 'stationary'], 'price': 22.27, 'quantity': 6}, {'name': 'pens', 'tags': ['writing', 'office', 'school', 'stationary'], 'price': 37.38, 'quantity': 1}, {'name': 'backpack', 'tags': ['school', 'travel', 'kids'], 'price': 183.12, 'quantity': 4}], 'storeLocation': 'Seattle', 'customer': {'gender': 'M', 'age': 52, 'email': 'rul@ipohu.vi', 'satisfaction': 2}, 'couponUsed': False, 'purchaseMethod': 'Online'}}, {'index': 14, 'code': 16500, 'errmsg': "Error=16500, RetryAfterMs=11, Details='Insert error.", 'op': {'_id': '5bd761dcae323e45a93cd122', 'saleDate': '2013-10-26T01:43:15.696Z', 'items': [{'name': 'notepad', 'tags': ['office', 'writing', 'school'], 'price': 28.91, 'quantity': 5}, {'name': 'notepad', 'tags': ['office', 'writing', 'school'], 'price': 33.55, 'quantity': 4}, {'name': 'notepad', 'tags': ['office', 'writing', 'school'], 'price': 7.25, 'quantity': 4}, {'name': 'binder', 'tags': ['school', 'general', 'organization'], 'price': 24.64, 'quantity': 3}, {'name': 'laptop', 'tags': ['electronics', 'school', 'office'], 'price': 864.08, 'quantity': 2}, {'name': 'pens', 'tags': ['writing', 'office', 'school', 'stationary'], 'price': 25.88, 'quantity': 3}, {'name': 'pens', 'tags': ['writing', 'office', 'school', 'stationary'], 'price': 32.63, 'quantity': 1}, {'name': 'printer paper', 'tags': ['office', 'stationary'], 'price': 42.95, 'quantity': 4}], 'storeLocation': 'Seattle', 'customer': {'gender': 'F', 'age': 20, 'email': 'wo@gu.tt', 'satisfaction': 4}, 'couponUsed': False, 'purchaseMethod': 'In store'}}, {'index': 15, 'code': 16500, 'errmsg': "Error=16500, RetryAfterMs=11, Details='Insert error.", 'op': {'_id': '5bd761dcae323e45a93cd123', 'saleDate': '2016-07-22T02:30:19.32Z', 'i ...
# Error en lote 8: batch op errors occurred, full error: {'writeErrors': [{'index': 11, 'code': 16500, 'errmsg': "Error=16500, RetryAfterMs=6, Details='Insert error.", 'op': {'_id': '5bd761dcae323e45a93cd151', 'saleDate': '2013-07-15T08:05:25.382Z', 'items': [{'name': 'envelopes', 'tags': ['stationary', 'office', 'general'], 'price': 16.8, 'quantity': 3}, {'name': 'backpack', 'tags': ['school', 'travel', 'kids'], 'price': 137.84, 'quantity': 5}, {'name': 'envelopes', 'tags': ['stationary', 'office', 'general'], 'price': 19.41, 'quantity': 9}, {'name': 'pens', 'tags': ['writing', 'office', 'school', 'stationary'], 'price': 20.71, 'quantity': 3}, {'name': 'laptop', 'tags': ['electronics', 'school', 'office'], 'price': 738.23, 'quantity': 5}], 'storeLocation': 'London', 'customer': {'gender': 'M', 'age': 27, 'email': 'vag@lez.sv', 'satisfaction': 5}, 'couponUsed': False, 'purchaseMethod': 'Online'}}, {'index': 12, 'code': 16500, 'errmsg': "Error=16500, RetryAfterMs=6, Details='Insert error.", 'op': {'_id': '5bd761dcae323e45a93cd152', 'saleDate': '2014-10-15T12:20:01.181Z', 'items': [{'name': 'notepad', 'tags': ['office', 'writing', 'school'], 'price': 29.77, 'quantity': 5}], 'storeLocation': 'Seattle', 'customer': {'gender': 'M', 'age': 59, 'email': 'pufin@zuhdaves.cw', 'satisfaction': 5}, 'couponUsed': True, 'purchaseMethod': 'In store'}}, {'index': 13, 'code': 16500, 'errmsg': "Error=16500, RetryAfterMs=6, Details='Insert error.", 'op': {'_id': '5bd761dcae323e45a93cd153', 'saleDate': '2013-01-06T01:14:19.899Z', 'items': [{'name': 'backpack', 'tags': ['school', 'travel', 'kids'], 'price': 112.24, 'quantity': 4}, {'name': 'laptop', 'tags': ['electronics', 'school', 'office'], 'price': 800.95, 'quantity': 3}, {'name': 'notepad', 'tags': ['office', 'writing', 'school'], 'price': 35.5, 'quantity': 5}, {'name': 'notepad', 'tags': ['office', 'writing', 'school'], 'price': 39.17, 'quantity': 5}, {'name': 'binder', 'tags': ['school', 'general', 'organization'], 'price': 20.45, 'quantity': 2}, {'name': 'pens', 'tags': ['writing', 'office', 'school', 'stationary'], 'price': 7.78, 'quantity': 2}], 'storeLocation': 'Denver', 'customer': {'gender': 'M', 'age': 71, 'email': 'ti@wihvufji.tt', 'satisfaction': 5}, 'couponUsed': False, 'purchaseMethod': 'In store'}}, {'index': 14, 'code': 16500, 'errmsg': "Error=16500, RetryAfterMs=6, Details='Insert error.", 'op': {'_id': '5bd761dcae323e45a93cd154', 'saleDate': '2017-10-02T18:22:59.759Z', 'items': [{'name': 'laptop', 'tags': ['electronics', 'school', 'office'], 'price': 469.81, 'quantity': 4}], 'storeLocation': 'New York', 'customer': {'gender': 'M', 'age': 49, 'email': 'jido@ca.com', 'satisfaction': 3}, 'couponUsed': False, 'purchaseMethod': 'In store'}}, {'index': 15, 'code': 16500, 'errmsg': "Error=16500, RetryAfterMs=6, Details='Insert error.", 'op': {'_id': '5bd761dcae323e45a93cd155', 'saleDate': '2015-03-23T10:49:50.798Z', 'items': [{'name': 'envelopes', 'tags': ['stationary', 'office', 'general'], 'price': 9.71, 'quantity': 6}, {'name': 'pens', 'tags': ['writing', 'office', 'school', 'stationary'], 'price': 15.22, 'quantity': 2}, {'name': 'binder', 'tags': ['school', 'general', 'organization'], 'price': 10.13, 'quantity': 8}, {'name': 'binder', 'tags': ['school', 'general', 'organization'], 'price': 11.25, 'quantity': 7}, {'name': 'notepad', 'tags': ['office', 'writing', 'school'], 'price': 32.3, 'quantity': 3}, {'name': 'backpack', 'tags': ['school', 'travel', 'kids'], 'price': 120.39, 'quantity': 5}], 'storeLocation': 'London', 'customer': {'gender': 'M', 'age': 58, 'email': 'vakur@upano.ax', 'satisfaction': 5}, 'couponUsed': False, 'purchaseMethod': 'Phone'}}, {'index': 16, 'code': 16500, 'errmsg': "Error=16500, RetryAfterMs=6, Details='Insert error.", 'op': {'_id': '5bd761dcae323e45a93cd156', 'saleDate': '2016-12-27T17:33:09.29Z', 'items': [{'name': 'notepad', 'tags': ['office', 'writing', 'school'], 'price': 33.29, 'quantity': 5}, {'name': 'envelopes', 'tags': ['stationary', 'office',  ...
# Error en lote 9: batch op errors occurred, full error: {'writeErrors': [{'index': 12, 'code': 16500, 'errmsg': "Error=16500, RetryAfterMs=10, Details='Insert error.", 'op': {'_id': '5bd761dcae323e45a93cd184', 'saleDate': '2016-03-08T00:38:53.581Z', 'items': [{'name': 'printer paper', 'tags': ['office', 'stationary'], 'price': 28.37, 'quantity': 9}, {'name': 'notepad', 'tags': ['office', 'writing', 'school'], 'price': 20.34, 'quantity': 3}, {'name': 'backpack', 'tags': ['school', 'travel', 'kids'], 'price': 46.54, 'quantity': 3}, {'name': 'pens', 'tags': ['writing', 'office', 'school', 'stationary'], 'price': 44.51, 'quantity': 2}, {'name': 'binder', 'tags': ['school', 'general', 'organization'], 'price': 12.9, 'quantity': 6}, {'name': 'laptop', 'tags': ['electronics', 'school', 'office'], 'price': 1543.39, 'quantity': 4}, {'name': 'pens', 'tags': ['writing', 'office', 'school', 'stationary'], 'price': 27.62, 'quantity': 1}, {'name': 'notepad', 'tags': ['office', 'writing', 'school'], 'price': 22.88, 'quantity': 2}], 'storeLocation': 'Denver', 'customer': {'gender': 'F', 'age': 46, 'email': 'veka@me.mw', 'satisfaction': 4}, 'couponUsed': False, 'purchaseMethod': 'In store'}}, {'index': 13, 'code': 16500, 'errmsg': "Error=16500, RetryAfterMs=10, Details='Insert error.", 'op': {'_id': '5bd761dcae323e45a93cd185', 'saleDate': '2017-12-06T15:05:43.851Z', 'items': [{'name': 'notepad', 'tags': ['office', 'writing', 'school'], 'price': 24.04, 'quantity': 5}, {'name': 'pens', 'tags': ['writing', 'office', 'school', 'stationary'], 'price': 7.44, 'quantity': 4}, {'name': 'backpack', 'tags': ['school', 'travel', 'kids'], 'price': 148.09, 'quantity': 2}, {'name': 'printer paper', 'tags': ['office', 'stationary'], 'price': 16.1, 'quantity': 4}, {'name': 'envelopes', 'tags': ['stationary', 'office', 'general'], 'price': 23.54, 'quantity': 7}, {'name': 'notepad', 'tags': ['office', 'writing', 'school'], 'price': 33.91, 'quantity': 5}, {'name': 'pens', 'tags': ['writing', 'office', 'school', 'stationary'], 'price': 31.94, 'quantity': 5}, {'name': 'binder', 'tags': ['school', 'general', 'organization'], 'price': 25.26, 'quantity': 5}, {'name': 'envelopes', 'tags': ['stationary', 'office', 'general'], 'price': 7.09, 'quantity': 4}, {'name': 'laptop', 'tags': ['electronics', 'school', 'office'], 'price': 1103.31, 'quantity': 5}], 'storeLocation': 'Austin', 'customer': {'gender': 'F', 'age': 65, 'email': 'gihsasozu@uw.az', 'satisfaction': 4}, 'couponUsed': False, 'purchaseMethod': 'In store'}}, {'index': 14, 'code': 16500, 'errmsg': "Error=16500, RetryAfterMs=10, Details='Insert error.", 'op': {'_id': '5bd761dcae323e45a93cd186', 'saleDate': '2015-02-23T16:27:13.846Z', 'items': [{'name': 'binder', 'tags': ['school', 'general', 'organization'], 'price': 19.18, 'quantity': 4}, {'name': 'envelopes', 'tags': ['stationary', 'office', 'general'], 'price': 9.45, 'quantity': 7}, {'name': 'laptop', 'tags': ['electronics', 'school', 'office'], 'price': 1403.56, 'quantity': 4}, {'name': 'notepad', 'tags': ['office', 'writing', 'school'], 'price': 24.18, 'quantity': 2}, {'name': 'binder', 'tags': ['school', 'general', 'organization'], 'price': 15.53, 'quantity': 5}, {'name': 'envelopes', 'tags': ['stationary', 'office', 'general'], 'price': 10.14, 'quantity': 10}, {'name': 'pens', 'tags': ['writing', 'office', 'school', 'stationary'], 'price': 54.05, 'quantity': 1}], 'storeLocation': 'Seattle', 'customer': {'gender': 'F', 'age': 48, 'email': 'pebhag@hoj.gg', 'satisfaction': 3}, 'couponUsed': False, 'purchaseMethod': 'In store'}}, {'index': 15, 'code': 16500, 'errmsg': "Error=16500, RetryAfterMs=10, Details='Insert error.", 'op': {'_id': '5bd761dcae323e45a93cd187', 'saleDate': '2014-03-14T11:19:14.334Z', 'items': [{'name': 'envelopes', 'tags': ['stationary', 'office', 'general'], 'price': 23.53, 'quantity': 6}, {'name': 'envelopes', 'tags': ['stationary', 'office', 'general'], 'price': 10.13, 'quantity': 6}, {'name': 'binder', 'tags': ['school', 'general', 'orga ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 12
#      10 batch = data[i:i+batch_size]
#      11 try:
# ---> 12     collection.insert_many(batch, ordered=False)
#      13     print(f"Lote {i//batch_size+1} insertado con éxito ({len(batch)} docs)")
#      14 except Exception as e:
#
# File c:\Users\kgome\anaconda3\envs\myenv\lib\site-packages\pymongo\_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File c:\Users\kgome\anaconda3\envs\myenv\lib\site-packages\pymongo\synchronous\collection.py:975, in Collection.insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     973 blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     974 blk.ops = list(gen())
# --> 975 blk.execute(write_concern, session, _Op.INSERT)
#     976 return InsertManyResult(inserted_ids, write_concern.acknowledged)
#
# File c:\Users\kgome\anaconda3\envs\myenv\lib\site-packages\pymongo\synchronous\bulk.py:751, in _Bulk.execute(self, write_concern, session, operation)
#     749         return None
#     750 else:
# --> 751     return self.execute_command(generator, write_concern, session, operation)
#
# File c:\Users\kgome\anaconda3\envs\myenv\lib\site-packages\pymongo\synchronous\bulk.py:604, in _Bulk.execute_command(self, generator, write_concern, session, operation)
#     593     self._execute_command(
#     594         generator,
#     595         write_concern,
#    (...)
#     600         full_result,
#     601     )
#     603 client = self.collection.database.client
# --> 604 _ = client._retryable_write(
#     605     self.is_retryable,
#     606     retryable_bulk,
#     607     session,
#     608     operation,
#     609     bulk=self,  # type: ignore[arg-type]
#     610     operation_id=op_id,
#     611 )
#     613 if full_result["writeErrors"] or full_result["writeConcernErrors"]:
#     614     _raise_bulk_write_error(full_result)
#
# File c:\Users\kgome\anaconda3\envs\myenv\lib\site-packages\pymongo\synchronous\mongo_client.py:2082, in MongoClient._retryable_write(self, retryable, func, session, operation, bulk, operation_id)
#    2068 """Execute an operation with consecutive retries if possible
#    2069
#    2070 Returns func()'s return value on success. On error retries the same
#    (...)
#    2079 :param bulk: bulk abstraction to execute operations in bulk, defaults to None
#    2080 """
#    2081 with self._tmp_session(session) as s:
# -> 2082     return self._retry_with_session(retryable, func, s, bulk, operation, operation_id)
#
# File c:\Users\kgome\anaconda3\envs\myenv\lib\site-packages\pymongo\synchronous\mongo_client.py:1968, in MongoClient._retry_with_session(self, retryable, func, session, bulk, operation, operation_id)
#    1963 # Ensure that the options supports retry_writes and there is a valid session not in
#    1964 # transaction, otherwise, we will not support retry behavior for this txn.
#    1965 retryable = bool(
#    1966     retryable and self.options.retry_writes and session and not session.in_transaction
#    1967 )
# -> 1968 return self._retry_internal(
#    1969     func=func,
#    1970     session=session,
#    1971     bulk=bulk,
#    1972     operation=operation,
#    1973     retryable=retryable,
#    1974     operation_id=operation_id,
#    1975 )
#
# File c:\Users\kgome\anaconda3\envs\myenv\lib\site-packages\pymongo\_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File c:\Users\kgome\anaconda3\envs\myenv\lib\site-packages\pymongo\synchronous\mongo_client.py:2014, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1977 @_csot.apply
#    1978 def _retry_internal(
#    1979     self,
#    (...)
#    1988     operation_id: Optional[int] = None,
#    1989 ) -> T:
#    1990     """Internal retryable helper for all client transactions.
#    1991
#    1992     :param func: Callback function we want to retry
#    (...)
#    2001     :return: Output of the calling func()
#    2002     """
#    2003     return _ClientConnectionRetryable(
#    2004         mongo_client=self,
#    2005         func=func,
#    2006         bulk=bulk,
#    2007         operation=operation,
#    2008         is_read=is_read,
#    2009         session=session,
#    2010         read_pref=read_pref,
#    2011         address=address,
#    2012         retryable=retryable,
#    2013         operation_id=operation_id,
# -> 2014     ).run()
#
# File c:\Users\kgome\anaconda3\envs\myenv\lib\site-packages\pymongo\synchronous\mongo_client.py:2765, in _ClientConnectionRetryable.run(self)
#    2763 self._check_last_error(check_csot=True)
#    2764 try:
# -> 2765     return self._read() if self._is_read else self._write()
#    2766 except ServerSelectionTimeoutError:
#    2767     # The application may think the write was never attempted
#    2768     # if we raise ServerSelectionTimeoutError on the retry
#    2769     # attempt. Raise the original exception instead.
#    2770     self._check_last_error()
#
# File c:\Users\kgome\anaconda3\envs\myenv\lib\site-packages\pymongo\synchronous\mongo_client.py:2897, in _ClientConnectionRetryable._write(self)
#    2889         if self._retrying:
#    2890             _debug_log(
#    2891                 _COMMAND_LOGGER,
#    2892                 message=f"Retrying write attempt number {self._attempt_number}",
#    (...)
#    2895                 operationId=self._operation_id,
#    2896             )
# -> 2897         return self._func(self._session, conn, self._retryable)  # type: ignore
#    2898 except PyMongoError as exc:
#    2899     if not self._retryable:
#
# File c:\Users\kgome\anaconda3\envs\myenv\lib\site-packages\pymongo\synchronous\bulk.py:593, in _Bulk.execute_command.<locals>.retryable_bulk(session, conn, retryable)
#     590 def retryable_bulk(
#     591     session: Optional[ClientSession], conn: Connection, retryable: bool
#     592 ) -> None:
# --> 593     self._execute_command(
#     594         generator,
#     595         write_concern,
#     596         session,
#     597         conn,
#     598         op_id,
#     599         retryable,
#     600         full_result,
#     601     )
#
# File c:\Users\kgome\anaconda3\envs\myenv\lib\site-packages\pymongo\synchronous\bulk.py:538, in _Bulk._execute_command(self, generator, write_concern, session, conn, op_id, retryable, full_result, final_write_concern)
#     536 # Run as many ops as possible in one command.
#     537 if write_concern.acknowledged:
# --> 538     result, to_send = self._execute_batch(bwc, cmd, ops, client)
#     540     # Retryable writeConcernErrors halt the execution of this run.
#     541     wce = result.get("writeConcernError", {})
#
# File c:\Users\kgome\anaconda3\envs\myenv\lib\site-packages\pymongo\synchronous\bulk.py:462, in _Bulk._execute_batch(self, bwc, cmd, ops, client)
#     460 else:
#     461     request_id, msg, to_send = bwc.batch_command(cmd, ops)
# --> 462     result = self.write_command(bwc, cmd, request_id, msg, to_send, client)  # type: ignore[arg-type]
#     464 return result, to_send
#
# File c:\Users\kgome\anaconda3\envs\myenv\lib\site-packages\pymongo\synchronous\helpers.py:47, in _handle_reauth.<locals>.inner(*args, **kwargs)
#      44 from pymongo.synchronous.pool import Connection
#      46 try:
# ---> 47     return func(*args, **kwargs)
#      48 except OperationFailure as exc:
#      49     if no_reauth:
#
# File c:\Users\kgome\anaconda3\envs\myenv\lib\site-packages\pymongo\synchronous\bulk.py:274, in _Bulk.write_command(self, bwc, cmd, request_id, msg, docs, client)
#     272     bwc._start(cmd, request_id, docs)
#     273 try:
# --> 274     reply = bwc.conn.write_command(request_id, msg, bwc.codec)  # type: ignore[misc]
#     275     duration = datetime.datetime.now() - bwc.start_time
#     276     if _COMMAND_LOGGER.isEnabledFor(logging.DEBUG):
#
# File c:\Users\kgome\anaconda3\envs\myenv\lib\site-packages\pymongo\synchronous\pool.py:501, in Connection.write_command(self, request_id, msg, codec_options)
#     493 """Send "insert" etc. command, returning response as a dict.
#     494
#     495 Can raise ConnectionFailure or OperationFailure.
#    (...)
#     498 :param msg: bytes, the command message.
#     499 """
#     500 self.send_message(msg, 0)
# --> 501 reply = self.receive_message(request_id)
#     502 result = reply.command_response(codec_options)
#     504 # Raises NotPrimaryError or OperationFailure.
#
# File c:\Users\kgome\anaconda3\envs\myenv\lib\site-packages\pymongo\synchronous\pool.py:469, in Connection.receive_message(self, request_id)
#     467 # Catch KeyboardInterrupt, CancelledError, etc. and cleanup.
#     468 except BaseException as error:
# --> 469     self._raise_connection_failure(error)
#
# File c:\Users\kgome\anaconda3\envs\myenv\lib\site-packages\pymongo\synchronous\pool.py:466, in Connection.receive_message(self, request_id)
#     461 """Receive a raw BSON message or raise ConnectionFailure.
#     462
#     463 If any exception is raised, the socket is closed.
#     464 """
#     465 try:
# --> 466     return receive_message(self, request_id, self.max_message_size)
#     467 # Catch KeyboardInterrupt, CancelledError, etc. and cleanup.
#     468 except BaseException as error:
#
# File c:\Users\kgome\anaconda3\envs\myenv\lib\site-packages\pymongo\network_layer.py:759, in receive_message(conn, request_id, max_message_size)
#     757         deadline = None
#     758 # Ignore the response's request id.
# --> 759 length, _, response_to, op_code = _UNPACK_HEADER(receive_data(conn, 16, deadline))
#     760 # No request_id for exhaust cursor "getMore".
#     761 if request_id is not None:
#
# File c:\Users\kgome\anaconda3\envs\myenv\lib\site-packages\pymongo\network_layer.py:343, in receive_data(conn, length, deadline)
#     339 try:
#     340     # Use the legacy wait_for_read cancellation approach on PyPy due to PYTHON-5011.
#     341     # also use it on Windows due to PYTHON-5405
#     342     if _PYPY or _WINDOWS:
# --> 343         wait_for_read(conn, deadline)
#     344         if _csot.get_timeout() and deadline is not None:
#     345             conn.set_conn_timeout(max(deadline - time.monotonic(), 0))
#
# File c:\Users\kgome\anaconda3\envs\myenv\lib\site-packages\pymongo\network_layer.py:316, in wait_for_read(conn, deadline)
#     314     else:
#     315         timeout = _POLL_TIMEOUT
# --> 316     readable = conn.socket_checker.select(sock, read=True, timeout=timeout)
#     317 if conn.cancel_context.cancelled:
#     318     raise _OperationCancelled("operation cancelled")
#
# File c:\Users\kgome\anaconda3\envs\myenv\lib\site-packages\pymongo\socket_checker.py:77, in SocketChecker.select(self, sock, read, write, timeout)
#      75 rlist = [sock] if read else []
#      76 wlist = [sock] if write else []
# ---> 77 res = select.select(rlist, wlist, [sock], timeout)
#      78 # select returns a 3-tuple of lists of objects that are
#      79 # ready: subsets of the first three arguments. Return
#      80 # True if any of the lists are not empty.
#      81 return any(res)
#
# KeyboardInterrupt:

# %%
failed = []
for doc in cleaned:
    try:
        collection.insert_one(doc)
    except Exception as e:
        print("falló")
        failed.append(doc)

print(f"{len(failed)} documentos fallaron")

#Intentando un documento a la vez porque por batches de 50 tampoco funciona
# Out:
# 0 documentos fallaron

# %%
# Test connection
print(f"Total listings: {collection.count_documents({})}")
# Out:
# Total listings: 5000

# %% [markdown]
# ### EDA Adicional

# %%
# Connection string (replace with your connection details)
client = MongoClient("mongodb://localhost:27017/")
# OR for Atlas: 
# client = MongoClient("mongodb+srv://username:password@cluster.mongodb.net/")

db = client.sample_supplies
collection = db.sales

# Test connection
print(f"Total listings: {collection.count_documents({})}")
# Out:
# Total listings: 5000

# %%
pipeline = [
    # 1. Desenrollar los items del array
    {"$unwind": "$items"},

    # 2. Agrupar por fecha y por tipo de producto, sumando cantidad e ingreso
    {
        "$group": {
            "_id": {
                "date": {"$dateToString": {"format": "%Y-%m-%d", "date": "$saleDate"}},
                "product": "$items.name"
            },
            "total_quantity": {"$sum": "$items.quantity"},
            "total_revenue": {
                "$sum": {
                    "$multiply": ["$items.quantity", "$items.price"]
                }
            }
        }
    },

    # 3. Ordenar por fecha y producto
    {
        "$sort": {
            "_id.date": 1,
            "_id.product": 1
        }
    }
]
results = collection.aggregate(pipeline)
df = pd.DataFrame(results)
df = df.join(pd.json_normalize(df["_id"]))
df = df.drop(columns=["_id"])
df
# Out:
#        total_quantity total_revenue        date        product
# 0                   5        398.60  2013-01-01       backpack
# 1                  29        673.57  2013-01-01         binder
# 2                  14        257.50  2013-01-01      envelopes
# 3                   6       6316.90  2013-01-01         laptop
# 4                   4        118.04  2013-01-01        notepad
# ...               ...           ...         ...            ...
# 10131              26        574.32  2017-12-31         binder
# 10132              33        412.09  2017-12-31      envelopes
# 10133              17        236.74  2017-12-31        notepad
# 10134              20        783.84  2017-12-31           pens
# 10135               9        357.57  2017-12-31  printer paper
#
# [10136 rows x 4 columns]

# %%
df.to_csv("sales_report.csv", index=False)

# %%
# Contar cuántas transacciones hay en total
total_transactions = collection.count_documents({})

# Pipeline para contar en cuántas transacciones aparece cada producto
pipeline = [
    {"$unwind": "$items"},
    {"$group": {"_id": "$items.name", "num_transactions": {"$sum": 1}}}
]

results = list(collection.aggregate(pipeline))
df = pd.DataFrame(results)

# Calcular la probabilidad de aparición de cada producto
df["total_transactions"] = total_transactions
df["probability"] = df["num_transactions"] / df["total_transactions"]

df = df.rename(columns={"_id": "product"})
df
# Out:
#          product  num_transactions  total_transactions  probability
# 0       backpack              2309                5000       0.4618
# 1           pens              4559                5000       0.9118
# 2  printer paper              2246                5000       0.4492
# 3        notepad              6872                5000       1.3744
# 4      envelopes              4505                5000       0.9010
# 5         binder              4676                5000       0.9352
# 6         laptop              2271                5000       0.4542

# %%
def df_clients(collection):
    pipeline = [
        # 1. Desenrollar items
        {"$unwind": "$items"},

        # 2. Agregar total por item
        {"$addFields": {"item_total": {"$multiply": ["$items.quantity", "$items.price"]}}},

        # 3. Agrupar por venta para sumar totales y capturar cliente
        {"$group": {
            "_id": "$_id",
            "saleDate": {"$first": "$saleDate"},
            "customer": {"$first": "$customer"},
            "customer_gender": {"$first": "$customer.gender"},
            "customer_age": {"$first": "$customer.age"},
            "customer_satisfaction": {"$first": "$customer.satisfaction"},
            "couponUsed": {"$first": "$couponUsed"},
            "storeLocation": {"$first": "$storeLocation"},
            "purchaseMethod": {"$first": "$purchaseMethod"},
            "total_revenue": {"$sum": "$item_total"},
            "items": {"$push": "$items"}
        }},

        # 4. Ordenar por fecha (opcional)
        {"$sort": {"saleDate": 1}}
    ]

    # Ejecutar pipeline
    results = list(collection.aggregate(pipeline))

    # Convertir a DataFrame
    df_clients = pd.DataFrame(results)

    # Opcional: aplanar la columna de items si quieres analizar los productos individuales
    df_clients["num_items"] = df_clients["items"].apply(lambda x: len(x))
    df_clients['total_revenue'] = df_clients['total_revenue'].apply(lambda x: float(x.to_decimal()))

    return df_clients

df_clients = df_clients(collection)
df_clients['total_revenue'].sum()
# Out:
# 9894572.27

# %%
def crear_df(collection):
    pipeline = [
    # 1. Desenrollar los items del array
        {"$unwind": "$items"},

        # 2. Agrupar por fecha y por tipo de producto, sumando cantidad e ingreso
        {
            "$group": {
                "_id": {
                    "date": {"$dateToString": {"format": "%Y-%m-%d", "date": "$saleDate"}},
                    "product": "$items.name"
                },
                "total_quantity": {"$sum": "$items.quantity"},
                "total_revenue": {
                    "$sum": {
                        "$multiply": ["$items.quantity", "$items.price"]
                    }
                }
            }
        },

        # 3. Ordenar por fecha y producto
        {
            "$sort": {
                "_id.date": 1,
                "_id.product": 1
            }
        }
    ]
    results = collection.aggregate(pipeline)
    df = pd.DataFrame(results)
    df = df.join(pd.json_normalize(df["_id"]))
    df = df.drop(columns=["_id"])
    return df

df = crear_df(collection)
df['total_revenue'] = df['total_revenue'].apply(lambda x: float(x.to_decimal()))
df['total_revenue'].sum()
# Out:
# 9894572.27

# %%
df['date']
# Out:
#        total_quantity  total_revenue        date        product
# 0                   5         398.60  2013-01-01       backpack
# 1                  29         673.57  2013-01-01         binder
# 2                  14         257.50  2013-01-01      envelopes
# 3                   6        6316.90  2013-01-01         laptop
# 4                   4         118.04  2013-01-01        notepad
# ...               ...            ...         ...            ...
# 10131              26         574.32  2017-12-31         binder
# 10132              33         412.09  2017-12-31      envelopes
# 10133              17         236.74  2017-12-31        notepad
# 10134              20         783.84  2017-12-31           pens
# 10135               9         357.57  2017-12-31  printer paper
#
# [10136 rows x 4 columns]

# %%
pipeline = [
    {
        "$group": {
            "_id": "$customer.email",   # agrupa por email
            "num_purchases": { "$sum": 1 }, # cuenta cuántos documentos (ventas) tiene
            "total_revenue": { 
                "$sum": { 
                    "$sum": { 
                        "$map": { 
                            "input": "$items", 
                            "as": "item", 
                            "in": { "$multiply": ["$$item.price", "$$item.quantity"] }
                        } 
                    } 
                } 
            }
        }
    },
    {
        "$sort": { "num_purchases": -1 } # ordenar por número de compras descendente
    }
]

results = list(collection.aggregate(pipeline))
df_clients = pd.DataFrame(results)
df_clients = df_clients.rename(columns={"_id": "email"})

# %%
df_clients
# Out:
#                    email  num_purchases total_revenue
# 0          citdet@ale.tn              1       3169.27
# 1       rir@zovkanpod.gy              1        407.90
# 2       paat@ezegijej.eh              1        245.11
# 3           amtu@ijus.bi              1       3985.28
# 4     gijulnik@dejawu.fj              1       1333.12
# ...                  ...            ...           ...
# 4995      vozafob@sid.yt              1       3646.19
# 4996        ivoilu@na.sy              1       1631.99
# 4997   hovahhob@zomoj.ps              1        668.53
# 4998      seh@hajtomo.bj              1       1961.97
# 4999  bevtod@fedpehog.sg              1       1513.34
#
# [5000 rows x 3 columns]

# %%
df_clients[df_clients['saleDate']=='2013-01-01']
# Out:
# Empty DataFrame
# Columns: [_id, saleDate, customer, customer_gender, customer_age, customer_satisfaction, couponUsed, storeLocation, purchaseMethod, total_revenue, items, num_items]
# Index: []

# %%
a
